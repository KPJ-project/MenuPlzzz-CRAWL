# %%
from ast import literal_eval
from bs4 import BeautifulSoup
from requests import get

def macdonald(page):
    '''
    맥도날드 페이지에서, 메뉴들을 크롤링 해온다.
    '''
    
    #url, header 설정
    url = "https://www.mcdelivery.co.kr/kr/browse/menu.html?daypartId=2&catId={}".format(page)
    u_a = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.82 Safari/537.36"
    
    #응답 값을 받아오고, bs 객체로 변환한다.
    response = requests.get(url, headers={"USER-AGENT":u_a})
    soup = BeautifulSoup(response.text, 'html.parser')
        
    #상품부분에 해당하는 부분을 find, find_all로 필터링 한다.
    products_box_soup = soup.find("div", {"id":"product-cards"})
    products = products_box_soup.find_all("a", {"class": "btn btn-block action-create btn-yellow"})

    #필터링 된 정보를 재가공 한다.
    informations = []
    for product in products:
        data = product.get('onclick')
        if data.startswith('onProductClick'):
            informations.append(data[len('onProductClick('): -1])
    
    result = []
    for information in informations:
        temp_dict = {}
        menu = literal_eval(information)
        temp_dict['name'] = menu['name']
        temp_dict['price'] = menu['price'][2:]
        temp_dict['category'] = menu['cat']
        result.append(temp_dict)
        
    #결과를 DB에 삽입한다.
    for a in result:
        print(a)
    print("\n\n")
    
    
macdonald(10)
macdonald(11)
macdonald(13)
macdonald(14)
macdonald(15)
macdonald(16)
# Out:
# {'name': '딸기 칠러', 'price': '3,100', 'category': '추천 메뉴'}
# {'name': '콘 스프', 'price': '2,100', 'category': '추천 메뉴'}
# {'name': '베이컨 에그 맥머핀™', 'price': '4,600', 'category': '추천 메뉴'}
# {'name': '상하이 치킨 스낵랩', 'price': '3,900', 'category': '추천 메뉴'}
# {'name': '골든 모짜렐라 치즈스틱 2조각', 'price': '2,600', 'category': '추천 메뉴'}
#
#
#
# {'name': '상하이 치킨 스낵랩', 'price': '2,600', 'category': '맥모닝 & 세트'}
# {'name': '에그 맥머핀™', 'price': '3,100', 'category': '맥모닝 & 세트'}
# {'name': '베이컨 에그 맥머핀™', 'price': '3,500', 'category': '맥모닝 & 세트'}
# {'name': '베이컨 토마토 머핀', 'price': '3,600', 'category': '맥모닝 & 세트'}
# {'name': '소시지 에그 맥머핀™', 'price': '3,500', 'category': '맥모닝 & 세트'}
# {'name': '소시지 맥머핀™', 'price': '2,600', 'category': '맥모닝 & 세트'}
# {'name': '디럭스 브렉퍼스트', 'price': '5,200', 'category': '맥모닝 & 세트'}
# {'name': '핫케익 2조각', 'price': '2,600', 'category': '맥모닝 & 세트'}
# {'name': '핫케익 3조각', 'price': '3,400', 'category': '맥모닝 & 세트'}
# {'name': '딸기잼', 'price': '200', 'category': '맥모닝 & 세트'}
# {'name': '핫케익 시럽 추가', 'price': '300', 'category': '맥모닝 & 세트'}
# {'name': '핫케익 버터 추가', 'price': '200', 'category': '맥모닝 & 세트'}
#
#
#
# {'name': '콘 스프', 'price': '2,100', 'category': '스낵 & 사이드'}
# {'name': '상하이 치킨 스낵랩', 'price': '2,600', 'category': '스낵 & 사이드'}
# {'name': '골든 모짜렐라 치즈스틱 2조각', 'price': '2,600', 'category': '스낵 & 사이드'}
# {'name': '골든 모짜렐라 치즈스틱 4조각', 'price': '4,400', 'category': '스낵 & 사이드'}
# {'name': '해쉬 브라운', 'price': '1,600', 'category': '스낵 & 사이드'}
# {'name': '파인애플 후룻컵', 'price': '2,200', 'category': '스낵 & 사이드'}
#
#
#
# {'name': '딸기 칠러', 'price': '3,100', 'category': '음료'}
# {'name': '골든 키위 칠러', 'price': '3,100', 'category': '음료'}
# {'name': '자두 칠러', 'price': '3,100', 'category': '음료'}
# {'name': '코카-콜라®', 'price': '1,600', 'category': '음료'}
# {'name': '코카-콜라® 제로', 'price': '1,600', 'category': '음료'}
# {'name': '스프라이트®', 'price': '1,600', 'category': '음료'}
# {'name': '환타®', 'price': '1,600', 'category': '음료'}
# {'name': '카페라떼', 'price': '3,100', 'category': '음료'}
# {'name': '카푸치노', 'price': '3,100', 'category': '음료'}
# {'name': '아메리카노', 'price': '2,600', 'category': '음료'}
# {'name': '에스프레소', 'price': '2,100', 'category': '음료'}
# {'name': '프리미엄 로스트™ 원두커피', 'price': '2,100', 'category': '음료'}
# {'name': '아이스 카페라떼 (시럽 없음)', 'price': '3,100', 'category': '음료'}
# {'name': '아이스 아메리카노 (시럽 없음)', 'price': '2,600', 'category': '음료'}
# {'name': '아이스 커피 (시럽 없음)', 'price': '1,600', 'category': '음료'}
# {'name': '바닐라 쉐이크', 'price': '3,100', 'category': '음료'}
# {'name': '딸기 쉐이크', 'price': '3,100', 'category': '음료'}
# {'name': '초코 쉐이크', 'price': '3,100', 'category': '음료'}
# {'name': '오렌지 주스 (캔)', 'price': '2,400', 'category': '음료'}
# {'name': '우유', 'price': '2,100', 'category': '음료'}
# {'name': '생수', 'price': '1,800', 'category': '음료'}
#
#
#
# {'name': '애플 파이', 'price': '1,600', 'category': '디저트'}
# {'name': '오레오 맥플러리®', 'price': '3,100', 'category': '디저트'}
# {'name': '초코 선데이 아이스크림', 'price': '2,100', 'category': '디저트'}
# {'name': '카라멜 선데이 아이스크림', 'price': '2,100', 'category': '디저트'}
# {'name': '딸기 선데이 아이스크림', 'price': '2,100', 'category': '디저트'}
# {'name': '바닐라 선데이 아이스크림', 'price': '2,100', 'category': '디저트'}
#
#
#
# {'name': '에그 맥머핀™', 'price': '4,400', 'category': '해피밀®'}
# {'name': '베이컨 에그 맥머핀™', 'price': '4,600', 'category': '해피밀®'}
# {'name': '소시지 에그 맥머핀™', 'price': '4,600', 'category': '해피밀®'}
# {'name': '소시지 맥머핀™', 'price': '4,400', 'category': '해피밀®'}
# {'name': '핫케익', 'price': '4,400', 'category': '해피밀®'}

# %%
from ast import literal_eval
from bs4 import BeautifulSoup
from requests import get

def momstouch(page):
    '''
    맥도날드 페이지에서, 메뉴들을 크롤링 해온다.
    '''
    
    #url, header 설정
    url = "https://www.mcdelivery.co.kr/kr/browse/menu.html?daypartId=2&catId={}".format(page)
    u_a = "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/48.0.2564.82 Safari/537.36"
    
    #응답 값을 받아오고, bs 객체로 변환한다.
    response = requests.get(url, headers={"USER-AGENT":u_a})
    soup = BeautifulSoup(response.text, 'html.parser')
        
    #상품부분에 해당하는 부분을 find, find_all로 필터링 한다.
    products_box_soup = soup.find("div", {"id":"product-cards"})
    products = products_box_soup.find_all("a", {"class": "btn btn-block action-create btn-yellow"})

    #필터링 된 정보를 재가공 한다.
    informations = []
    for product in products:
        data = product.get('onclick')
        if data.startswith('onProductClick'):
            informations.append(data[len('onProductClick('): -1])
    
    result = []
    for information in informations:
        temp_dict = {}
        menu = literal_eval(information)
        temp_dict['name'] = menu['name']
        temp_dict['price'] = menu['price'][2:]
        temp_dict['category'] = menu['cat']
        result.append(temp_dict)
        
    #결과를 DB에 삽입한다.
    for a in result:
        print(a)
    print("\n\n")
    
    
macdonald(10)
macdonald(11)
macdonald(13)
macdonald(14)
macdonald(15)
macdonald(16)
